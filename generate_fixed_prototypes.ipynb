# %% [markdown]
# ### ETF Prototypes (K <= d)
#
# https://github.com/NeuralCollapseApplications/ImbalancedLearning/blob/main/models/resnet.py#L326
#
# $K$ = number of classes
#
# $d$ = representation space dimension

# %%
import numpy as np
import torch
import random

seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

def generate_random_orthogonal_matrix(feat_dim, num_classes):
    a = np.random.random(size=(feat_dim, num_classes))
    P, _ = np.linalg.qr(a)
    P = torch.tensor(P).float()
    assert torch.allclose(torch.matmul(P.T, P), torch.eye(num_classes), atol=1e-07), torch.max(torch.abs(torch.matmul(P.T, P) - torch.eye(num_classes)))
    return P

d = 16
K = 4

P = generate_random_orthogonal_matrix(feat_dim=d, num_classes=K)
I = torch.eye(K)
one = torch.ones(K, K)
M_star = np.sqrt(K / (K-1)) * torch.matmul(P, I-((1/K) * one))
M_star = M_star.cuda()

print(M_star)
print(M_star.shape)

def test_ETF_prototype(M_star):
    # print norm of each vector in M_star
    for i, m in enumerate(M_star):
        print(f"m_{i} l2 norm: {torch.norm(m, dim=None, p=2)}.")

    for i, m in enumerate(M_star):
        for j, n in enumerate(M_star):
            if i != j:
                dot_prod = torch.dot(m,n)
                m_norm = torch.norm(m, dim=None, p=2)
                n_norm = torch.norm(n, dim=None, p=2)
                cosine_sim = dot_prod / (m_norm * n_norm)
                cosine_sim = torch.clamp(cosine_sim, -1.0, 1.0)
                pairwise_angle = torch.acos(cosine_sim)
                print(f"Pairwise angle between m_{i} and m_{j} is: {pairwise_angle}.")

test_ETF_prototype(M_star=M_star.T)
# Out:
# tensor([[-0.2537,  0.4420,  0.1176, -0.3060],
#         [-0.2382, -0.1224, -0.2090,  0.5695],
#         [-0.2723,  0.2513, -0.3602,  0.3812],
#         [-0.1654,  0.0027,  0.0830,  0.0798],
#         [-0.1469,  0.2387,  0.1004, -0.1922],
#         [-0.2090, -0.0974,  0.1086,  0.1978],
#         [-0.1633,  0.4138, -0.1584, -0.0920],
#         [-0.2177, -0.1740,  0.3836,  0.0081],
#         [-0.3088,  0.3803,  0.1920, -0.2635],
#         [-0.2600, -0.1840,  0.3300,  0.1140],
#         [-0.2156,  0.1455, -0.3207,  0.3908],
#         [-0.1686,  0.3161, -0.0727, -0.0748],
#         [-0.4177, -0.2744,  0.4265,  0.2656],
#         [-0.3872,  0.2776,  0.0057,  0.1040],
#         [-0.0870,  0.0567, -0.0946,  0.1249],
#         [-0.2610, -0.0577,  0.4087, -0.0899]], device='cuda:0')
# torch.Size([16, 4])
# m_0 l2 norm: 1.0.
# m_1 l2 norm: 0.9999999403953552.
# m_2 l2 norm: 1.0.
# m_3 l2 norm: 1.0.
# Pairwise angle between m_0 and m_1 is: 1.9106332063674927.
# Pairwise angle between m_0 and m_2 is: 1.9106332063674927.
# Pairwise angle between m_0 and m_3 is: 1.9106332063674927.
# Pairwise angle between m_1 and m_0 is: 1.9106332063674927.
# Pairwise angle between m_1 and m_2 is: 1.9106332063674927.
# Pairwise angle between m_1 and m_3 is: 1.9106333255767822.
# Pairwise angle between m_2 and m_0 is: 1.9106332063674927.
# Pairwise angle between m_2 and m_1 is: 1.9106332063674927.
# Pairwise angle between m_2 and m_3 is: 1.9106332063674927.
# Pairwise angle between m_3 and m_0 is: 1.9106332063674927.
# Pairwise angle between m_3 and m_1 is: 1.9106333255767822.
# Pairwise angle between m_3 and m_2 is: 1.9106332063674927.

# %% [markdown]
# ### Prototype generation (HPN 2019)
#
# https://github.com/psmmettes/hpn/blob/master/prototypes.py
#
# $K$ = number of classes
#
# $d$ = representation space dimension

# %%
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

d = 16
K = 100

def prototype_loss(prototypes):
    product = torch.matmul(prototypes, prototypes.t()) + 1
    product -= 2. * torch.diag(torch.diag(product))
    loss = product.max(dim=1)[0]
    return loss.mean(), product.max()

prototypes = torch.randn(K, d)
prototypes = nn.Parameter(F.normalize(prototypes, p=2, dim=1))
optimizer = optim.SGD([prototypes], lr=0.1, momentum=0.9)
epochs = 1_000_000
for i in range(epochs):
    loss1, sep = prototype_loss(prototypes)
    loss = loss1
    loss.backward()
    optimizer.step()

    prototypes = nn.Parameter(F.normalize(prototypes, p=2, dim=1))
    optimizer = optim.SGD([prototypes], lr=0.1, momentum=0.9)
    # print("%03d/%d: %.4f\r" %(i, epochs, sep))

# %%
prototypes.shape
# Out:
# torch.Size([100, 16])

# %%
test_ETF_prototype(M_star=prototypes)
# Out:
# m_0 l2 norm: 1.0.
# m_1 l2 norm: 1.0.
# m_2 l2 norm: 0.9999999403953552.
# m_3 l2 norm: 1.0.
# m_4 l2 norm: 1.0.
# m_5 l2 norm: 1.0.
# m_6 l2 norm: 0.9999999403953552.
# m_7 l2 norm: 1.0.
# m_8 l2 norm: 0.9999999403953552.
# m_9 l2 norm: 0.9999999403953552.
# m_10 l2 norm: 1.0.
# m_11 l2 norm: 0.9999999403953552.
# m_12 l2 norm: 1.0.
# m_13 l2 norm: 1.0.
# m_14 l2 norm: 0.9999999403953552.
# m_15 l2 norm: 0.9999999403953552.
# m_16 l2 norm: 0.9999999403953552.
# m_17 l2 norm: 0.9999999403953552.
# m_18 l2 norm: 0.9999999403953552.
# m_19 l2 norm: 0.9999999403953552.
# m_20 l2 norm: 1.0.
# m_21 l2 norm: 1.0.
# m_22 l2 norm: 0.9999999403953552.
# m_23 l2 norm: 1.0000001192092896.
# m_24 l2 norm: 1.0.
# m_25 l2 norm: 0.9999999403953552.
# m_26 l2 norm: 1.0.
# m_27 l2 norm: 1.0.
# m_28 l2 norm: 1.0.
# m_29 l2 norm: 0.9999999403953552.
# m_30 l2 norm: 0.9999999403953552.
# m_31 l2 norm: 1.0.
# m_32 l2 norm: 0.9999999403953552.
# m_33 l2 norm: 1.0.
# m_34 l2 norm: 0.9999999403953552.
# m_35 l2 norm: 1.0.
# m_36 l2 norm: 1.0.
# m_37 l2 norm: 0.9999999403953552.
# m_38 l2 norm: 1.0.
# m_39 l2 norm: 0.9999999403953552.
# m_40 l2 norm: 0.9999999403953552.
# m_41 l2 norm: 0.9999999403953552.
# m_42 l2 norm: 1.0.
# m_43 l2 norm: 1.0.
# m_44 l2 norm: 1.0.
# m_45 l2 norm: 1.0.
# m_46 l2 norm: 1.0.
# m_47 l2 norm: 1.0.
# m_48 l2 norm: 1.0.
# m_49 l2 norm: 0.9999999403953552.
# m_50 l2 norm: 1.0.
# m_51 l2 norm: 1.0.
# m_52 l2 norm: 1.0.
# m_53 l2 norm: 0.9999999403953552.
# m_54 l2 norm: 0.9999999403953552.
# m_55 l2 norm: 0.9999999403953552.
# m_56 l2 norm: 0.9999999403953552.
# m_57 l2 norm: 1.0.
# m_58 l2 norm: 1.0.
# m_59 l2 norm: 1.0.
# m_60 l2 norm: 1.0.
# m_61 l2 norm: 1.0.
# m_62 l2 norm: 0.9999999403953552.
# m_63 l2 norm: 0.9999999403953552.
# m_64 l2 norm: 0.9999999403953552.
# m_65 l2 norm: 0.9999999403953552.
# m_66 l2 norm: 1.0.
# m_67 l2 norm: 1.0.
# m_68 l2 norm: 1.0.
# m_69 l2 norm: 0.9999999403953552.
# m_70 l2 norm: 1.0.
# m_71 l2 norm: 1.0.
# m_72 l2 norm: 1.0.
# m_73 l2 norm: 0.9999998807907104.
# m_74 l2 norm: 0.9999999403953552.
# m_75 l2 norm: 1.0.
# m_76 l2 norm: 0.9999999403953552.
# m_77 l2 norm: 0.9999999403953552.
# m_78 l2 norm: 1.0.
# m_79 l2 norm: 1.0.
# m_80 l2 norm: 0.9999999403953552.
# m_81 l2 norm: 1.0.
# m_82 l2 norm: 0.9999999403953552.
# m_83 l2 norm: 1.0.
# m_84 l2 norm: 1.0.
# m_85 l2 norm: 0.9999999403953552.
# m_86 l2 norm: 1.0.
# m_87 l2 norm: 1.0.
# m_88 l2 norm: 1.0.
# m_89 l2 norm: 1.0.
# m_90 l2 norm: 0.9999999403953552.
# m_91 l2 norm: 1.0.
# m_92 l2 norm: 1.0.
# m_93 l2 norm: 1.0.
# m_94 l2 norm: 0.9999999403953552.
# m_95 l2 norm: 1.0.
# m_96 l2 norm: 0.9999999403953552.
# m_97 l2 norm: 1.0.
# m_98 l2 norm: 1.0.
# m_99 l2 norm: 1.0.
# Pairwise angle between m_0 and m_1 is: 2.040083646774292.
# Pairwise angle between m_0 and m_2 is: 1.7067265510559082.
# Pairwise angle between m_0 and m_3 is: 1.8825618028640747.
# Pairwise angle between m_0 and m_4 is: 1.3578555583953857.
# Pairwise angle between m_0 and m_5 is: 1.3593605756759644.
# Pairwise angle between m_0 and m_6 is: 1.7835309505462646.
# Pairwise angle between m_0 and m_7 is: 2.0348854064941406.
# Pairwise angle between m_0 and m_8 is: 1.4165241718292236.
# Pairwise angle between m_0 and m_9 is: 1.5963752269744873.
# Pairwise angle between m_0 and m_10 is: 1.4316052198410034.
# Pairwise angle between m_0 and m_11 is: 1.8497060537338257.
# Pairwise angle between m_0 and m_12 is: 1.3600903749465942.
# Pairwise angle between m_0 and m_13 is: 1.6139509677886963.
# Pairwise angle between m_0 and m_14 is: 1.3565645217895508.
# Pairwise angle between m_0 and m_15 is: 1.9694983959197998.
# Pairwise angle between m_0 and m_16 is: 1.9622474908828735.
# Pairwise angle between m_0 and m_17 is: 1.6446378231048584.
# Pairwise angle between m_0 and m_18 is: 1.826606273651123.
# Pairwise angle between m_0 and m_19 is: 1.3584197759628296.
# Pairwise angle between m_0 and m_20 is: 1.3585315942764282.
# Pairwise angle between m_0 and m_21 is: 1.4170953035354614.
# Pairwise angle between m_0 and m_22 is: 1.5391507148742676.
# Pairwise angle between m_0 and m_23 is: 1.357896089553833.
# Pairwise angle between m_0 and m_24 is: 1.3621617555618286.
# Pairwise angle between m_0 and m_25 is: 1.8105533123016357.
# Pairwise angle between m_0 and m_26 is: 1.7971203327178955.
# Pairwise angle between m_0 and m_27 is: 1.3597946166992188.
# Pairwise angle between m_0 and m_28 is: 2.0530009269714355.
# Pairwise angle between m_0 and m_29 is: 1.3578141927719116.
# Pairwise angle between m_0 and m_30 is: 1.3588283061981201.
# Pairwise angle between m_0 and m_31 is: 1.8303334712982178.
# Pairwise angle between m_0 and m_32 is: 1.378509521484375.
# Pairwise angle between m_0 and m_33 is: 1.3569523096084595.
# Pairwise angle between m_0 and m_34 is: 1.899043321609497.
# Pairwise angle between m_0 and m_35 is: 1.358596920967102.
# Pairwise angle between m_0 and m_36 is: 2.0096874237060547.
# Pairwise angle between m_0 and m_37 is: 1.3563956022262573.
# Pairwise angle between m_0 and m_38 is: 1.5087836980819702.
# Pairwise angle between m_0 and m_39 is: 1.7818999290466309.
# Pairwise angle between m_0 and m_40 is: 1.4206373691558838.
# Pairwise angle between m_0 and m_41 is: 1.3578072786331177.
# Pairwise angle between m_0 and m_42 is: 1.3677978515625.
# Pairwise angle between m_0 and m_43 is: 1.7924116849899292.
# Pairwise angle between m_0 and m_44 is: 1.3566339015960693.
# Pairwise angle between m_0 and m_45 is: 1.6965020895004272.
# Pairwise angle between m_0 and m_46 is: 1.590583324432373.
# Pairwise angle between m_0 and m_47 is: 1.3575537204742432.
# Pairwise angle between m_0 and m_48 is: 1.8505825996398926.
# Pairwise angle between m_0 and m_49 is: 1.3995592594146729.
# Pairwise angle between m_0 and m_50 is: 1.3571676015853882.
# Pairwise angle between m_0 and m_51 is: 1.6801451444625854.
# Pairwise angle between m_0 and m_52 is: 1.9554078578948975.
# Pairwise angle between m_0 and m_53 is: 1.586024284362793.
# Pairwise angle between m_0 and m_54 is: 2.0274362564086914.
# Pairwise angle between m_0 and m_55 is: 1.7472305297851562.
# Pairwise angle between m_0 and m_56 is: 1.987931728363037.
# Pairwise angle between m_0 and m_57 is: 1.3586828708648682.
# Pairwise angle between m_0 and m_58 is: 2.0644519329071045.
# Pairwise angle between m_0 and m_59 is: 1.3765305280685425.
# Pairwise angle between m_0 and m_60 is: 1.8510487079620361.
# Pairwise angle between m_0 and m_61 is: 1.3891046047210693.
# Pairwise angle between m_0 and m_62 is: 1.9573230743408203.
# Pairwise angle between m_0 and m_63 is: 1.4173190593719482.
# Pairwise angle between m_0 and m_64 is: 1.3590422868728638.
# Pairwise angle between m_0 and m_65 is: 1.39765465259552.
# Pairwise angle between m_0 and m_66 is: 1.417076826095581.
# Pairwise angle between m_0 and m_67 is: 1.4619356393814087.
# Pairwise angle between m_0 and m_68 is: 1.3588708639144897.
# Pairwise angle between m_0 and m_69 is: 1.6630133390426636.
# Pairwise angle between m_0 and m_70 is: 1.8985024690628052.
# Pairwise angle between m_0 and m_71 is: 1.3597491979599.
# Pairwise angle between m_0 and m_72 is: 1.4344439506530762.
# Pairwise angle between m_0 and m_73 is: 1.3575903177261353.
# Pairwise angle between m_0 and m_74 is: 1.357904314994812.
# Pairwise angle between m_0 and m_75 is: 1.740519642829895.
# Pairwise angle between m_0 and m_76 is: 1.3579699993133545.
# Pairwise angle between m_0 and m_77 is: 1.3585296869277954.
# Pairwise angle between m_0 and m_78 is: 1.7179834842681885.
# Pairwise angle between m_0 and m_79 is: 1.900160312652588.
# Pairwise angle between m_0 and m_80 is: 1.5765055418014526.
# Pairwise angle between m_0 and m_81 is: 1.7245771884918213.
# Pairwise angle between m_0 and m_82 is: 1.8053020238876343.
# Pairwise angle between m_0 and m_83 is: 1.9694409370422363.
# Pairwise angle between m_0 and m_84 is: 1.4545141458511353.
# Pairwise angle between m_0 and m_85 is: 1.8501789569854736.
# Pairwise angle between m_0 and m_86 is: 1.3575963973999023.
# Pairwise angle between m_0 and m_87 is: 1.356297254562378.
# Pairwise angle between m_0 and m_88 is: 1.9516520500183105.
# Pairwise angle between m_0 and m_89 is: 1.357802391052246.
# Pairwise angle between m_0 and m_90 is: 1.3587868213653564.
# Pairwise angle between m_0 and m_91 is: 1.4240684509277344.
# Pairwise angle between m_0 and m_92 is: 1.7829475402832031.
# Pairwise angle between m_0 and m_93 is: 1.359100580215454.
# Pairwise angle between m_0 and m_94 is: 1.5025088787078857.
# Pairwise angle between m_0 and m_95 is: 1.3588300943374634.
# Pairwise angle between m_0 and m_96 is: 1.398110032081604.
# Pairwise angle between m_0 and m_97 is: 1.3779315948486328.
# Pairwise angle between m_0 and m_98 is: 1.6037648916244507.
# Pairwise angle between m_0 and m_99 is: 1.360201120376587.
# Pairwise angle between m_1 and m_0 is: 2.040083646774292.
# Pairwise angle between m_1 and m_2 is: 1.7388873100280762.
# Pairwise angle between m_1 and m_3 is: 1.3573724031448364.
# Pairwise angle between m_1 and m_4 is: 1.5775426626205444.
# Pairwise angle between m_1 and m_5 is: 1.3577160835266113.
# Pairwise angle between m_1 and m_6 is: 1.7837398052215576.
# Pairwise angle between m_1 and m_7 is: 1.3571237325668335.
# Pairwise angle between m_1 and m_8 is: 1.357845425605774.
# Pairwise angle between m_1 and m_9 is: 1.3575942516326904.
# Pairwise angle between m_1 and m_10 is: 1.8410909175872803.
# Pairwise angle between m_1 and m_11 is: 1.9057568311691284.
# Pairwise angle between m_1 and m_12 is: 1.3575178384780884.
# Pairwise angle between m_1 and m_13 is: 1.4362390041351318.
# Pairwise angle between m_1 and m_14 is: 1.8608448505401611.
# Pairwise angle between m_1 and m_15 is: 1.405229091644287.
# Pairwise angle between m_1 and m_16 is: 1.3572043180465698.
# Pairwise angle between m_1 and m_17 is: 1.3572449684143066.
# Pairwise angle between m_1 and m_18 is: 1.3578214645385742.
# Pairwise angle between m_1 and m_19 is: 2.035280704498291.
# Pairwise angle between m_1 and m_20 is: 1.809443473815918.
# Pairwise angle between m_1 and m_21 is: 1.3592122793197632.
# Pairwise angle between m_1 and m_22 is: 1.3604403734207153.
# Pairwise angle between m_1 and m_23 is: 1.8650755882263184.
# Pairwise angle between m_1 and m_24 is: 1.6310852766036987.
# Pairwise angle between m_1 and m_25 is: 1.3579659461975098.
# Pairwise angle between m_1 and m_26 is: 1.3580281734466553.
# Pairwise angle between m_1 and m_27 is: 1.9158542156219482.
# Pairwise angle between m_1 and m_28 is: 1.357631802558899.
# Pairwise angle between m_1 and m_29 is: 1.9044594764709473.
# Pairwise angle between m_1 and m_30 is: 1.8821452856063843.
# Pairwise angle between m_1 and m_31 is: 1.446698546409607.
# Pairwise angle between m_1 and m_32 is: 1.6726536750793457.
# Pairwise angle between m_1 and m_33 is: 1.9358900785446167.
# Pairwise angle between m_1 and m_34 is: 1.587775707244873.
# Pairwise angle between m_1 and m_35 is: 1.3578510284423828.
# Pairwise angle between m_1 and m_36 is: 1.3800311088562012.
# Pairwise angle between m_1 and m_37 is: 1.8423397541046143.
# Pairwise angle between m_1 and m_38 is: 1.7107038497924805.
# Pairwise angle between m_1 and m_39 is: 1.3576351404190063.
# Pairwise angle between m_1 and m_40 is: 2.0412914752960205.
# Pairwise angle between m_1 and m_41 is: 1.6142204999923706.
# Pairwise angle between m_1 and m_42 is: 1.3587367534637451.
# Pairwise angle between m_1 and m_43 is: 1.3574247360229492.
# Pairwise angle between m_1 and m_44 is: 1.5459375381469727.
# Pairwise angle between m_1 and m_45 is: 1.3580138683319092.
# Pairwise angle between m_1 and m_46 is: 1.7689905166625977.
# Pairwise angle between m_1 and m_47 is: 1.3578424453735352.
# Pairwise angle between m_1 and m_48 is: 1.6686935424804688.
# Pairwise angle between m_1 and m_49 is: 1.6906359195709229.
# Pairwise angle between m_1 and m_50 is: 1.3585569858551025.
# Pairwise angle between m_1 and m_51 is: 1.3892773389816284.
# Pairwise angle between m_1 and m_52 is: 1.8884247541427612.
# Pairwise angle between m_1 and m_53 is: 1.3587794303894043.
# Pairwise angle between m_1 and m_54 is: 1.4312529563903809.
# Pairwise angle between m_1 and m_55 is: 1.3594759702682495.
# Pairwise angle between m_1 and m_56 is: 1.357348084449768.
# Pairwise angle between m_1 and m_57 is: 1.500696063041687.
# Pairwise angle between m_1 and m_58 is: 1.3574013710021973.
# Pairwise angle between m_1 and m_59 is: 1.7676479816436768.
# Pairwise angle between m_1 and m_60 is: 1.3643615245819092.
# Pairwise angle between m_1 and m_61 is: 1.6539744138717651.
# Pairwise angle between m_1 and m_62 is: 1.3568822145462036.
# Pairwise angle between m_1 and m_63 is: 1.4446991682052612.
# Pairwise angle between m_1 and m_64 is: 2.0172312259674072.
# Pairwise angle between m_1 and m_65 is: 1.4040699005126953.
# Pairwise angle between m_1 and m_66 is: 1.3669570684432983.
# Pairwise angle between m_1 and m_67 is: 1.7749695777893066.
# Pairwise angle between m_1 and m_68 is: 1.6023154258728027.
# Pairwise angle between m_1 and m_69 is: 1.7868369817733765.
# Pairwise angle between m_1 and m_70 is: 1.3807381391525269.
# Pairwise angle between m_1 and m_71 is: 1.668668508529663.
# Pairwise angle between m_1 and m_72 is: 1.9678713083267212.
# Pairwise angle between m_1 and m_73 is: 1.3581252098083496.
# Pairwise angle between m_1 and m_74 is: 1.3570399284362793.
# Pairwise angle between m_1 and m_75 is: 1.3593918085098267.
# Pairwise angle between m_1 and m_76 is: 1.8959436416625977.
# Pairwise angle between m_1 and m_77 is: 1.7998970746994019.
# Pairwise angle between m_1 and m_78 is: 1.3597609996795654.
# Pairwise angle between m_1 and m_79 is: 1.7397091388702393.
# Pairwise angle between m_1 and m_80 is: 1.505568027496338.
# Pairwise angle between m_1 and m_81 is: 1.4426867961883545.
# Pairwise angle between m_1 and m_82 is: 1.3596272468566895.
# Pairwise angle between m_1 and m_83 is: 1.695205569267273.
# Pairwise angle between m_1 and m_84 is: 1.875959873199463.
# Pairwise angle between m_1 and m_85 is: 1.358370065689087.
# Pairwise angle between m_1 and m_86 is: 1.3577474355697632.
# Pairwise angle between m_1 and m_87 is: 1.8009088039398193.
# Pairwise angle between m_1 and m_88 is: 1.3582732677459717.
# Pairwise angle between m_1 and m_89 is: 1.8950177431106567.
# Pairwise angle between m_1 and m_90 is: 1.3881001472473145.
# Pairwise angle between m_1 and m_91 is: 1.3588738441467285.
# Pairwise angle between m_1 and m_92 is: 1.3578904867172241.
# Pairwise angle between m_1 and m_93 is: 1.6957093477249146.
# Pairwise angle between m_1 and m_94 is: 1.6845439672470093.
# Pairwise angle between m_1 and m_95 is: 1.997908115386963.
# Pairwise angle between m_1 and m_96 is: 2.025740623474121.
# Pairwise angle between m_1 and m_97 is: 2.062851667404175.
# Pairwise angle between m_1 and m_98 is: 1.7778353691101074.
# Pairwise angle between m_1 and m_99 is: 1.3710925579071045.
# Pairwise angle between m_2 and m_0 is: 1.7067265510559082.
# Pairwise angle between m_2 and m_1 is: 1.7388873100280762.
# Pairwise angle between m_2 and m_3 is: 1.4381245374679565.
# Pairwise angle between m_2 and m_4 is: 1.564178228378296.
# Pairwise angle between m_2 and m_5 is: 1.3584496974945068.
# Pairwise angle between m_2 and m_6 is: 1.3585762977600098.
# Pairwise angle between m_2 and m_7 is: 1.3572975397109985.
# Pairwise angle between m_2 and m_8 is: 1.9715683460235596.
# Pairwise angle between m_2 and m_9 is: 1.3589873313903809.
# Pairwise angle between m_2 and m_10 is: 1.420809030532837.
# Pairwise angle between m_2 and m_11 is: 1.41633939743042.
# Pairwise angle between m_2 and m_12 is: 1.3910069465637207.
# Pairwise angle between m_2 and m_13 is: 1.3578743934631348.
# Pairwise angle between m_2 and m_14 is: 1.8369544744491577.
# Pairwise angle between m_2 and m_15 is: 1.8912560939788818.
# Pairwise angle between m_2 and m_16 is: 1.6388213634490967.
# Pairwise angle between m_2 and m_17 is: 1.866518497467041.
# Pairwise angle between m_2 and m_18 is: 1.876173496246338.
# Pairwise angle between m_2 and m_19 is: 1.3630480766296387.
# Pairwise angle between m_2 and m_20 is: 1.3887877464294434.
# Pairwise angle between m_2 and m_21 is: 2.1199097633361816.
# Pairwise angle between m_2 and m_22 is: 1.795732021331787.
# Pairwise angle between m_2 and m_23 is: 1.3588461875915527.
# Pairwise angle between m_2 and m_24 is: 1.7812353372573853.
# Pairwise angle between m_2 and m_25 is: 1.908556580543518.
# Pairwise angle between m_2 and m_26 is: 1.8677375316619873.
# Pairwise angle between m_2 and m_27 is: 1.3753011226654053.
# Pairwise angle between m_2 and m_28 is: 1.8272943496704102.
# Pairwise angle between m_2 and m_29 is: 1.7174468040466309.
# Pairwise angle between m_2 and m_30 is: 1.7266253232955933.
# Pairwise angle between m_2 and m_31 is: 1.6707289218902588.
# Pairwise angle between m_2 and m_32 is: 1.8154428005218506.
# Pairwise angle between m_2 and m_33 is: 1.4387555122375488.
# Pairwise angle between m_2 and m_34 is: 1.3600424528121948.
# Pairwise angle between m_2 and m_35 is: 1.8408353328704834.
# Pairwise angle between m_2 and m_36 is: 1.3582990169525146.
# Pairwise angle between m_2 and m_37 is: 1.6871814727783203.
# Pairwise angle between m_2 and m_38 is: 1.7137842178344727.
# Pairwise angle between m_2 and m_39 is: 1.4850090742111206.
# Pairwise angle between m_2 and m_40 is: 1.358674168586731.
# Pairwise angle between m_2 and m_41 is: 1.3576130867004395.
# Pairwise angle between m_2 and m_42 is: 1.4698359966278076.
# Pairwise angle between m_2 and m_43 is: 1.3593966960906982.
# Pairwise angle between m_2 and m_44 is: 1.3573037385940552.
# Pairwise angle between m_2 and m_45 is: 1.3576836585998535.
# Pairwise angle between m_2 and m_46 is: 1.3590158224105835.
# Pairwise angle between m_2 and m_47 is: 2.0694468021392822.
# Pairwise angle between m_2 and m_48 is: 1.3578070402145386.
# Pairwise angle between m_2 and m_49 is: 1.358712077140808.
# Pairwise angle between m_2 and m_50 is: 2.0203282833099365.
# Pairwise angle between m_2 and m_51 is: 1.3595672845840454.
# Pairwise angle between m_2 and m_52 is: 1.3584165573120117.
# Pairwise angle between m_2 and m_53 is: 1.3589541912078857.
# Pairwise angle between m_2 and m_54 is: 1.3578283786773682.
# Pairwise angle between m_2 and m_55 is: 2.103982448577881.
# Pairwise angle between m_2 and m_56 is: 1.3838423490524292.
# Pairwise angle between m_2 and m_57 is: 1.4716339111328125.
# Pairwise angle between m_2 and m_58 is: 1.3586797714233398.
# Pairwise angle between m_2 and m_59 is: 1.3580137491226196.
# Pairwise angle between m_2 and m_60 is: 1.3577816486358643.
# Pairwise angle between m_2 and m_61 is: 1.807624340057373.
# Pairwise angle between m_2 and m_62 is: 1.7882531881332397.
# Pairwise angle between m_2 and m_63 is: 1.777236819267273.
# Pairwise angle between m_2 and m_64 is: 1.3606995344161987.
# Pairwise angle between m_2 and m_65 is: 1.7766153812408447.
# Pairwise angle between m_2 and m_66 is: 1.8752307891845703.
# Pairwise angle between m_2 and m_67 is: 1.562183141708374.
# Pairwise angle between m_2 and m_68 is: 1.3739521503448486.
# Pairwise angle between m_2 and m_69 is: 2.025482654571533.
# Pairwise angle between m_2 and m_70 is: 1.440963864326477.
# Pairwise angle between m_2 and m_71 is: 1.357924222946167.
# Pairwise angle between m_2 and m_72 is: 1.3602104187011719.
# Pairwise angle between m_2 and m_73 is: 1.4731571674346924.
# Pairwise angle between m_2 and m_74 is: 1.716728925704956.
# Pairwise angle between m_2 and m_75 is: 1.4572645425796509.
# Pairwise angle between m_2 and m_76 is: 1.3589143753051758.
# Pairwise angle between m_2 and m_77 is: 1.9165174961090088.
# Pairwise angle between m_2 and m_78 is: 1.3703486919403076.
# Pairwise angle between m_2 and m_79 is: 1.4901621341705322.
# Pairwise angle between m_2 and m_80 is: 1.3765137195587158.
# Pairwise angle between m_2 and m_81 is: 1.67142915725708.
# Pairwise angle between m_2 and m_82 is: 1.3569380044937134.
# Pairwise angle between m_2 and m_83 is: 1.7536189556121826.
# Pairwise angle between m_2 and m_84 is: 1.8634674549102783.
# Pairwise angle between m_2 and m_85 is: 1.3579636812210083.
# Pairwise angle between m_2 and m_86 is: 2.006748676300049.
# Pairwise angle between m_2 and m_87 is: 2.1257245540618896.
# Pairwise angle between m_2 and m_88 is: 1.54787278175354.
# Pairwise angle between m_2 and m_89 is: 1.3577111959457397.
# Pairwise angle between m_2 and m_90 is: 1.468410611152649.
# Pairwise angle between m_2 and m_91 is: 1.7002067565917969.
# Pairwise angle between m_2 and m_92 is: 1.4437423944473267.
# Pairwise angle between m_2 and m_93 is: 1.3581141233444214.
# Pairwise angle between m_2 and m_94 is: 1.41568124294281.
# Pairwise angle between m_2 and m_95 is: 1.5813651084899902.
# Pairwise angle between m_2 and m_96 is: 1.6720168590545654.
# Pairwise angle between m_2 and m_97 is: 1.5505576133728027.
# Pairwise angle between m_2 and m_98 is: 1.7933235168457031.
# Pairwise angle between m_2 and m_99 is: 1.585790753364563.
# Pairwise angle between m_3 and m_0 is: 1.8825618028640747.
# Pairwise angle between m_3 and m_1 is: 1.3573724031448364.
# Pairwise angle between m_3 and m_2 is: 1.4381245374679565.
# Pairwise angle between m_3 and m_4 is: 1.7406669855117798.
# Pairwise angle between m_3 and m_5 is: 1.3821711540222168.
# Pairwise angle between m_3 and m_6 is: 1.3799939155578613.
# Pairwise angle between m_3 and m_7 is: 1.6512231826782227.
# Pairwise angle between m_3 and m_8 is: 1.4554067850112915.
# Pairwise angle between m_3 and m_9 is: 1.3627634048461914.
# Pairwise angle between m_3 and m_10 is: 1.8738622665405273.
# Pairwise angle between m_3 and m_11 is: 1.8385708332061768.
# Pairwise angle between m_3 and m_12 is: 1.3581688404083252.
# Pairwise angle between m_3 and m_13 is: 1.3580963611602783.
# Pairwise angle between m_3 and m_14 is: 1.3579649925231934.
# Pairwise angle between m_3 and m_15 is: 1.65573251247406.
# Pairwise angle between m_3 and m_16 is: 1.3569155931472778.
# Pairwise angle between m_3 and m_17 is: 1.8155968189239502.
# Pairwise angle between m_3 and m_18 is: 1.384109616279602.
# Pairwise angle between m_3 and m_19 is: 1.3576581478118896.
# Pairwise angle between m_3 and m_20 is: 1.4641242027282715.
# Pairwise angle between m_3 and m_21 is: 1.8534038066864014.
# Pairwise angle between m_3 and m_22 is: 1.5199713706970215.
# Pairwise angle between m_3 and m_23 is: 1.3586833477020264.
# Pairwise angle between m_3 and m_24 is: 1.5078591108322144.
# Pairwise angle between m_3 and m_25 is: 1.357696771621704.
# Pairwise angle between m_3 and m_26 is: 1.357255458831787.
# Pairwise angle between m_3 and m_27 is: 1.9839675426483154.
# Pairwise angle between m_3 and m_28 is: 1.3584794998168945.
# Pairwise angle between m_3 and m_29 is: 1.7746920585632324.
# Pairwise angle between m_3 and m_30 is: 1.970550298690796.
# Pairwise angle between m_3 and m_31 is: 1.3589571714401245.
# Pairwise angle between m_3 and m_32 is: 1.717711329460144.
# Pairwise angle between m_3 and m_33 is: 2.0709025859832764.
# Pairwise angle between m_3 and m_34 is: 1.8205008506774902.
# Pairwise angle between m_3 and m_35 is: 1.6603329181671143.
# Pairwise angle between m_3 and m_36 is: 1.359015703201294.
# Pairwise angle between m_3 and m_37 is: 1.6313776969909668.
# Pairwise angle between m_3 and m_38 is: 1.873634934425354.
# Pairwise angle between m_3 and m_39 is: 1.3576546907424927.
# Pairwise angle between m_3 and m_40 is: 1.650175929069519.
# Pairwise angle between m_3 and m_41 is: 1.3579134941101074.
# Pairwise angle between m_3 and m_42 is: 1.9720836877822876.
# Pairwise angle between m_3 and m_43 is: 1.5224372148513794.
# Pairwise angle between m_3 and m_44 is: 1.5309654474258423.
# Pairwise angle between m_3 and m_45 is: 1.8272250890731812.
# Pairwise angle between m_3 and m_46 is: 1.3566908836364746.
# Pairwise angle between m_3 and m_47 is: 1.9934098720550537.
# Pairwise angle between m_3 and m_48 is: 1.438896894454956.
# Pairwise angle between m_3 and m_49 is: 1.7583662271499634.
# Pairwise angle between m_3 and m_50 is: 1.3683199882507324.
# Pairwise angle between m_3 and m_51 is: 1.369876503944397.
# Pairwise angle between m_3 and m_52 is: 1.3581342697143555.
# Pairwise angle between m_3 and m_53 is: 1.507551670074463.
# Pairwise angle between m_3 and m_54 is: 1.4784799814224243.
# Pairwise angle between m_3 and m_55 is: 2.0310816764831543.
# Pairwise angle between m_3 and m_56 is: 1.4489946365356445.
# Pairwise angle between m_3 and m_57 is: 2.0691311359405518.
# Pairwise angle between m_3 and m_58 is: 1.463094711303711.
# Pairwise angle between m_3 and m_59 is: 1.9581854343414307.
# Pairwise angle between m_3 and m_60 is: 1.4858968257904053.
# Pairwise angle between m_3 and m_61 is: 1.3582606315612793.
# Pairwise angle between m_3 and m_62 is: 1.6355255842208862.
# Pairwise angle between m_3 and m_63 is: 1.5439432859420776.
# Pairwise angle between m_3 and m_64 is: 1.3584718704223633.
# Pairwise angle between m_3 and m_65 is: 1.4249886274337769.
# Pairwise angle between m_3 and m_66 is: 1.5230902433395386.
# Pairwise angle between m_3 and m_67 is: 1.687915325164795.
# Pairwise angle between m_3 and m_68 is: 2.150850772857666.
# Pairwise angle between m_3 and m_69 is: 1.5534383058547974.
# Pairwise angle between m_3 and m_70 is: 1.3586914539337158.
# Pairwise angle between m_3 and m_71 is: 1.712664246559143.
# Pairwise angle between m_3 and m_72 is: 1.7405043840408325.
# Pairwise angle between m_3 and m_73 is: 1.891305685043335.
# Pairwise angle between m_3 and m_74 is: 1.356995701789856.
# Pairwise angle between m_3 and m_75 is: 1.8958930969238281.
# Pairwise angle between m_3 and m_76 is: 1.3570795059204102.
# Pairwise angle between m_3 and m_77 is: 1.9227644205093384.
# Pairwise angle between m_3 and m_78 is: 1.3587324619293213.
# Pairwise angle between m_3 and m_79 is: 1.3590025901794434.
# Pairwise angle between m_3 and m_80 is: 1.3645260334014893.
# Pairwise angle between m_3 and m_81 is: 1.3586146831512451.
# Pairwise angle between m_3 and m_82 is: 1.4284306764602661.
# Pairwise angle between m_3 and m_83 is: 1.3785914182662964.
# Pairwise angle between m_3 and m_84 is: 1.7120286226272583.
# Pairwise angle between m_3 and m_85 is: 1.3665072917938232.
# Pairwise angle between m_3 and m_86 is: 1.929948091506958.
# Pairwise angle between m_3 and m_87 is: 1.3581918478012085.
# Pairwise angle between m_3 and m_88 is: 1.814948558807373.
# Pairwise angle between m_3 and m_89 is: 1.9611262083053589.
# Pairwise angle between m_3 and m_90 is: 1.357496976852417.
# Pairwise angle between m_3 and m_91 is: 1.3579885959625244.
# Pairwise angle between m_3 and m_92 is: 1.3583828210830688.
# Pairwise angle between m_3 and m_93 is: 1.6928249597549438.
# Pairwise angle between m_3 and m_94 is: 1.7965267896652222.
# Pairwise angle between m_3 and m_95 is: 1.8736408948898315.
# Pairwise angle between m_3 and m_96 is: 1.4871299266815186.
# Pairwise angle between m_3 and m_97 is: 1.3668397665023804.
# Pairwise angle between m_3 and m_98 is: 1.8300385475158691.
# Pairwise angle between m_3 and m_99 is: 1.4902423620224.
# Pairwise angle between m_4 and m_0 is: 1.3578555583953857.
# Pairwise angle between m_4 and m_1 is: 1.5775426626205444.
# Pairwise angle between m_4 and m_2 is: 1.564178228378296.
# Pairwise angle between m_4 and m_3 is: 1.7406669855117798.
# Pairwise angle between m_4 and m_5 is: 1.9092164039611816.
# Pairwise angle between m_4 and m_6 is: 1.3808915615081787.
# Pairwise angle between m_4 and m_7 is: 1.6393518447875977.
# Pairwise angle between m_4 and m_8 is: 1.8506132364273071.
# Pairwise angle between m_4 and m_9 is: 1.3596117496490479.
# Pairwise angle between m_4 and m_10 is: 1.8285276889801025.
# Pairwise angle between m_4 and m_11 is: 1.6973528861999512.
# Pairwise angle between m_4 and m_12 is: 1.3589023351669312.
# Pairwise angle between m_4 and m_13 is: 1.8022983074188232.
# Pairwise angle between m_4 and m_14 is: 1.3578110933303833.
# Pairwise angle between m_4 and m_15 is: 1.3581442832946777.
# Pairwise angle between m_4 and m_16 is: 1.3591127395629883.
# Pairwise angle between m_4 and m_17 is: 1.7799204587936401.
# Pairwise angle between m_4 and m_18 is: 1.8623552322387695.
# Pairwise angle between m_4 and m_19 is: 1.414082646369934.
# Pairwise angle between m_4 and m_20 is: 1.5363245010375977.
# Pairwise angle between m_4 and m_21 is: 1.3629684448242188.
# Pairwise angle between m_4 and m_22 is: 1.4651031494140625.
# Pairwise angle between m_4 and m_23 is: 1.3936103582382202.
# Pairwise angle between m_4 and m_24 is: 1.3594467639923096.
# Pairwise angle between m_4 and m_25 is: 1.788487195968628.
# Pairwise angle between m_4 and m_26 is: 1.7279034852981567.
# Pairwise angle between m_4 and m_27 is: 1.3581379652023315.
# Pairwise angle between m_4 and m_28 is: 1.8847641944885254.
# Pairwise angle between m_4 and m_29 is: 1.3585278987884521.
# Pairwise angle between m_4 and m_30 is: 1.3577880859375.
# Pairwise angle between m_4 and m_31 is: 1.4973008632659912.
# Pairwise angle between m_4 and m_32 is: 1.3577377796173096.
# Pairwise angle between m_4 and m_33 is: 1.6162234544754028.
# Pairwise angle between m_4 and m_34 is: 1.7392818927764893.
# Pairwise angle between m_4 and m_35 is: 1.526535987854004.
# Pairwise angle between m_4 and m_36 is: 1.3579922914505005.
# Pairwise angle between m_4 and m_37 is: 1.9129780530929565.
# Pairwise angle between m_4 and m_38 is: 1.3580659627914429.
# Pairwise angle between m_4 and m_39 is: 2.0416111946105957.
# Pairwise angle between m_4 and m_40 is: 1.3579249382019043.
# Pairwise angle between m_4 and m_41 is: 1.632239818572998.
# Pairwise angle between m_4 and m_42 is: 1.363121509552002.
# Pairwise angle between m_4 and m_43 is: 1.358149766921997.
# Pairwise angle between m_4 and m_44 is: 1.3575884103775024.
# Pairwise angle between m_4 and m_45 is: 1.4309675693511963.
# Pairwise angle between m_4 and m_46 is: 1.8598304986953735.
# Pairwise angle between m_4 and m_47 is: 1.3574692010879517.
# Pairwise angle between m_4 and m_48 is: 1.3564302921295166.
# Pairwise angle between m_4 and m_49 is: 1.3586432933807373.
# Pairwise angle between m_4 and m_50 is: 1.357565999031067.
# Pairwise angle between m_4 and m_51 is: 2.1241087913513184.
# Pairwise angle between m_4 and m_52 is: 1.4718458652496338.
# Pairwise angle between m_4 and m_53 is: 1.3584893941879272.
# Pairwise angle between m_4 and m_54 is: 2.128044843673706.
# Pairwise angle between m_4 and m_55 is: 1.7893859148025513.
# Pairwise angle between m_4 and m_56 is: 1.939929485321045.
# Pairwise angle between m_4 and m_57 is: 1.3640878200531006.
# Pairwise angle between m_4 and m_58 is: 1.9600251913070679.
# Pairwise angle between m_4 and m_59 is: 2.0002315044403076.
# Pairwise angle between m_4 and m_60 is: 1.7319486141204834.
# Pairwise angle between m_4 and m_61 is: 1.5958542823791504.
# Pairwise angle between m_4 and m_62 is: 1.3571406602859497.
# Pairwise angle between m_4 and m_63 is: 1.9852852821350098.
# Pairwise angle between m_4 and m_64 is: 1.7678550481796265.
# Pairwise angle between m_4 and m_65 is: 1.89273202419281.
# Pairwise angle between m_4 and m_66 is: 1.3722399473190308.
# Pairwise angle between m_4 and m_67 is: 1.3576467037200928.
# Pairwise angle between m_4 and m_68 is: 1.4139859676361084.
# Pairwise angle between m_4 and m_69 is: 1.8121999502182007.
# Pairwise angle between m_4 and m_70 is: 1.9392890930175781.
# Pairwise angle between m_4 and m_71 is: 1.356894850730896.
# Pairwise angle between m_4 and m_72 is: 1.8658989667892456.
# Pairwise angle between m_4 and m_73 is: 1.7375446557998657.
# Pairwise angle between m_4 and m_74 is: 1.664816975593567.
# Pairwise angle between m_4 and m_75 is: 1.3581373691558838.
# Pairwise angle between m_4 and m_76 is: 1.3975577354431152.
# Pairwise angle between m_4 and m_77 is: 2.034677028656006.
# Pairwise angle between m_4 and m_78 is: 1.3598185777664185.
# Pairwise angle between m_4 and m_79 is: 1.8318158388137817.
# Pairwise angle between m_4 and m_80 is: 1.550660252571106.
# Pairwise angle between m_4 and m_81 is: 1.4805411100387573.
# Pairwise angle between m_4 and m_82 is: 1.3581913709640503.
# Pairwise angle between m_4 and m_83 is: 1.9658949375152588.
# Pairwise angle between m_4 and m_84 is: 1.3584901094436646.
# Pairwise angle between m_4 and m_85 is: 1.3788889646530151.
# Pairwise angle between m_4 and m_86 is: 1.357926607131958.
# Pairwise angle between m_4 and m_87 is: 1.668667197227478.
# Pairwise angle between m_4 and m_88 is: 1.3693773746490479.
# Pairwise angle between m_4 and m_89 is: 1.359004259109497.
# Pairwise angle between m_4 and m_90 is: 1.3593705892562866.
# Pairwise angle between m_4 and m_91 is: 1.3638701438903809.
# Pairwise angle between m_4 and m_92 is: 1.3794996738433838.
# Pairwise angle between m_4 and m_93 is: 1.6149154901504517.
# Pairwise angle between m_4 and m_94 is: 1.7555142641067505.
# Pairwise angle between m_4 and m_95 is: 1.3585337400436401.
# Pairwise angle between m_4 and m_96 is: 1.9809459447860718.
# Pairwise angle between m_4 and m_97 is: 1.7647360563278198.
# Pairwise angle between m_4 and m_98 is: 1.9129409790039062.
# Pairwise angle between m_4 and m_99 is: 1.5712600946426392.
# Pairwise angle between m_5 and m_0 is: 1.3593605756759644.
# Pairwise angle between m_5 and m_1 is: 1.3577160835266113.
# Pairwise angle between m_5 and m_2 is: 1.3584496974945068.
# Pairwise angle between m_5 and m_3 is: 1.3821711540222168.
# Pairwise angle between m_5 and m_4 is: 1.9092164039611816.
# Pairwise angle between m_5 and m_6 is: 1.4634989500045776.
# Pairwise angle between m_5 and m_7 is: 1.8582866191864014.
# Pairwise angle between m_5 and m_8 is: 1.3589997291564941.
# Pairwise angle between m_5 and m_9 is: 1.358245611190796.
# Pairwise angle between m_5 and m_10 is: 1.36653470993042.
# Pairwise angle between m_5 and m_11 is: 1.9988629817962646.
# Pairwise angle between m_5 and m_12 is: 1.3676207065582275.
# Pairwise angle between m_5 and m_13 is: 1.4260411262512207.
# Pairwise angle between m_5 and m_14 is: 1.8377851247787476.
# Pairwise angle between m_5 and m_15 is: 2.0616960525512695.
# Pairwise angle between m_5 and m_16 is: 1.7683923244476318.
# Pairwise angle between m_5 and m_17 is: 1.3570271730422974.
# Pairwise angle between m_5 and m_18 is: 1.3576593399047852.
# Pairwise angle between m_5 and m_19 is: 1.3591738939285278.
# Pairwise angle between m_5 and m_20 is: 1.7913222312927246.
# Pairwise angle between m_5 and m_21 is: 1.9925720691680908.
# Pairwise angle between m_5 and m_22 is: 1.3583132028579712.
# Pairwise angle between m_5 and m_23 is: 1.7077850103378296.
# Pairwise angle between m_5 and m_24 is: 1.9388439655303955.
# Pairwise angle between m_5 and m_25 is: 1.5296295881271362.
# Pairwise angle between m_5 and m_26 is: 1.708720326423645.
# Pairwise angle between m_5 and m_27 is: 1.5055571794509888.
# Pairwise angle between m_5 and m_28 is: 1.4935479164123535.
# Pairwise angle between m_5 and m_29 is: 1.9691177606582642.
# Pairwise angle between m_5 and m_30 is: 1.7327184677124023.
# Pairwise angle between m_5 and m_31 is: 1.7583006620407104.
# Pairwise angle between m_5 and m_32 is: 1.3898850679397583.
# Pairwise angle between m_5 and m_33 is: 1.700103759765625.
# Pairwise angle between m_5 and m_34 is: 1.3787143230438232.
# Pairwise angle between m_5 and m_35 is: 1.3694992065429688.
# Pairwise angle between m_5 and m_36 is: 1.8677961826324463.
# Pairwise angle between m_5 and m_37 is: 1.793137788772583.
# Pairwise angle between m_5 and m_38 is: 1.953751564025879.
# Pairwise angle between m_5 and m_39 is: 1.3574025630950928.
# Pairwise angle between m_5 and m_40 is: 1.7649431228637695.
# Pairwise angle between m_5 and m_41 is: 1.3963713645935059.
# Pairwise angle between m_5 and m_42 is: 1.518471360206604.
# Pairwise angle between m_5 and m_43 is: 1.5562115907669067.
# Pairwise angle between m_5 and m_44 is: 1.3579211235046387.
# Pairwise angle between m_5 and m_45 is: 1.7234174013137817.
# Pairwise angle between m_5 and m_46 is: 1.3572850227355957.
# Pairwise angle between m_5 and m_47 is: 1.3980528116226196.
# Pairwise angle between m_5 and m_48 is: 1.8447003364562988.
# Pairwise angle between m_5 and m_49 is: 2.0946617126464844.
# Pairwise angle between m_5 and m_50 is: 1.4369592666625977.
# Pairwise angle between m_5 and m_51 is: 1.367343783378601.
# Pairwise angle between m_5 and m_52 is: 2.0018057823181152.
# Pairwise angle between m_5 and m_53 is: 1.3580725193023682.
# Pairwise angle between m_5 and m_54 is: 1.3585317134857178.
# Pairwise angle between m_5 and m_55 is: 1.8412920236587524.
# Pairwise angle between m_5 and m_56 is: 1.3892070055007935.
# Pairwise angle between m_5 and m_57 is: 1.3846176862716675.
# Pairwise angle between m_5 and m_58 is: 1.5312654972076416.
# Pairwise angle between m_5 and m_59 is: 1.571250557899475.
# Pairwise angle between m_5 and m_60 is: 1.3585779666900635.
# Pairwise angle between m_5 and m_61 is: 1.360859751701355.
# Pairwise angle between m_5 and m_62 is: 2.009239673614502.
# Pairwise angle between m_5 and m_63 is: 1.3602076768875122.
# Pairwise angle between m_5 and m_64 is: 1.3590869903564453.
# Pairwise angle between m_5 and m_65 is: 1.3902796506881714.
# Pairwise angle between m_5 and m_66 is: 1.3594378232955933.
# Pairwise angle between m_5 and m_67 is: 1.8118293285369873.
# Pairwise angle between m_5 and m_68 is: 1.4650501012802124.
# Pairwise angle between m_5 and m_69 is: 1.5331213474273682.
# Pairwise angle between m_5 and m_70 is: 1.4948577880859375.
# Pairwise angle between m_5 and m_71 is: 1.357980489730835.
# Pairwise angle between m_5 and m_72 is: 1.359074354171753.
# Pairwise angle between m_5 and m_73 is: 1.358729362487793.
# Pairwise angle between m_5 and m_74 is: 1.6631766557693481.
# Pairwise angle between m_5 and m_75 is: 1.7737957239151.
# Pairwise angle between m_5 and m_76 is: 1.6207815408706665.
# Pairwise angle between m_5 and m_77 is: 1.3642586469650269.
# Pairwise angle between m_5 and m_78 is: 1.3994226455688477.
# Pairwise angle between m_5 and m_79 is: 1.5370235443115234.
# Pairwise angle between m_5 and m_80 is: 1.3979041576385498.
# Pairwise angle between m_5 and m_81 is: 1.7955551147460938.
# Pairwise angle between m_5 and m_82 is: 1.4634320735931396.
# Pairwise angle between m_5 and m_83 is: 2.1479952335357666.
# Pairwise angle between m_5 and m_84 is: 1.9535938501358032.
# Pairwise angle between m_5 and m_85 is: 1.8848034143447876.
# Pairwise angle between m_5 and m_86 is: 1.8172788619995117.
# Pairwise angle between m_5 and m_87 is: 1.727440357208252.
# Pairwise angle between m_5 and m_88 is: 1.3859379291534424.
# Pairwise angle between m_5 and m_89 is: 1.5547975301742554.
# Pairwise angle between m_5 and m_90 is: 1.3575804233551025.
# Pairwise angle between m_5 and m_91 is: 1.359055995941162.
# Pairwise angle between m_5 and m_92 is: 1.7874916791915894.
# Pairwise angle between m_5 and m_93 is: 1.4060635566711426.
# Pairwise angle between m_5 and m_94 is: 1.3799844980239868.
# Pairwise angle between m_5 and m_95 is: 1.9242149591445923.
# Pairwise angle between m_5 and m_96 is: 1.3818649053573608.
# Pairwise angle between m_5 and m_97 is: 1.6103051900863647.
# Pairwise angle between m_5 and m_98 is: 1.710527777671814.
# Pairwise angle between m_5 and m_99 is: 1.3586575984954834.
# Pairwise angle between m_6 and m_0 is: 1.7835309505462646.
# Pairwise angle between m_6 and m_1 is: 1.7837398052215576.
# Pairwise angle between m_6 and m_2 is: 1.3585762977600098.
# Pairwise angle between m_6 and m_3 is: 1.3799939155578613.
# Pairwise angle between m_6 and m_4 is: 1.3808915615081787.
# Pairwise angle between m_6 and m_5 is: 1.4634989500045776.
# Pairwise angle between m_6 and m_7 is: 1.3612526655197144.
# Pairwise angle between m_6 and m_8 is: 2.084671974182129.
# Pairwise angle between m_6 and m_9 is: 1.3583556413650513.
# Pairwise angle between m_6 and m_10 is: 1.3582406044006348.
# Pairwise angle between m_6 and m_11 is: 1.7813433408737183.
# Pairwise angle between m_6 and m_12 is: 1.7700456380844116.
# Pairwise angle between m_6 and m_13 is: 1.902413010597229.
# Pairwise angle between m_6 and m_14 is: 1.3572702407836914.
# Pairwise angle between m_6 and m_15 is: 1.3570207357406616.
# Pairwise angle between m_6 and m_16 is: 1.3575483560562134.
# Pairwise angle between m_6 and m_17 is: 1.3588290214538574.
# Pairwise angle between m_6 and m_18 is: 1.4651985168457031.
# Pairwise angle between m_6 and m_19 is: 1.495732307434082.
# Pairwise angle between m_6 and m_20 is: 1.8784579038619995.
# Pairwise angle between m_6 and m_21 is: 1.8610442876815796.
# Pairwise angle between m_6 and m_22 is: 1.5675636529922485.
# Pairwise angle between m_6 and m_23 is: 1.35785710811615.
# Pairwise angle between m_6 and m_24 is: 1.9265159368515015.
# Pairwise angle between m_6 and m_25 is: 1.735451340675354.
# Pairwise angle between m_6 and m_26 is: 1.8749043941497803.
# Pairwise angle between m_6 and m_27 is: 1.3927289247512817.
# Pairwise angle between m_6 and m_28 is: 1.3566555976867676.
# Pairwise angle between m_6 and m_29 is: 1.4812602996826172.
# Pairwise angle between m_6 and m_30 is: 1.7550495862960815.
# Pairwise angle between m_6 and m_31 is: 1.6046769618988037.
# Pairwise angle between m_6 and m_32 is: 1.6475419998168945.
# Pairwise angle between m_6 and m_33 is: 1.4617637395858765.
# Pairwise angle between m_6 and m_34 is: 1.3808584213256836.
# Pairwise angle between m_6 and m_35 is: 1.8806909322738647.
# Pairwise angle between m_6 and m_36 is: 1.3637666702270508.
# Pairwise angle between m_6 and m_37 is: 1.8172283172607422.
# Pairwise angle between m_6 and m_38 is: 1.3620792627334595.
# Pairwise angle between m_6 and m_39 is: 1.4698846340179443.
# Pairwise angle between m_6 and m_40 is: 1.3570908308029175.
# Pairwise angle between m_6 and m_41 is: 1.4905802011489868.
# Pairwise angle between m_6 and m_42 is: 1.8633136749267578.
# Pairwise angle between m_6 and m_43 is: 1.3576892614364624.
# Pairwise angle between m_6 and m_44 is: 1.3587440252304077.
# Pairwise angle between m_6 and m_45 is: 1.7359389066696167.
# Pairwise angle between m_6 and m_46 is: 1.3587875366210938.
# Pairwise angle between m_6 and m_47 is: 1.3745676279067993.
# Pairwise angle between m_6 and m_48 is: 1.3589385747909546.
# Pairwise angle between m_6 and m_49 is: 1.8847415447235107.
# Pairwise angle between m_6 and m_50 is: 1.727196216583252.
# Pairwise angle between m_6 and m_51 is: 1.6376701593399048.
# Pairwise angle between m_6 and m_52 is: 1.3602471351623535.
# Pairwise angle between m_6 and m_53 is: 1.9108914136886597.
# Pairwise angle between m_6 and m_54 is: 1.6692407131195068.
# Pairwise angle between m_6 and m_55 is: 2.073099374771118.
# Pairwise angle between m_6 and m_56 is: 1.3588438034057617.
# Pairwise angle between m_6 and m_57 is: 1.6053603887557983.
# Pairwise angle between m_6 and m_58 is: 1.7695648670196533.
# Pairwise angle between m_6 and m_59 is: 2.0215044021606445.
# Pairwise angle between m_6 and m_60 is: 1.382226824760437.
# Pairwise angle between m_6 and m_61 is: 1.3587476015090942.
# Pairwise angle between m_6 and m_62 is: 1.3719902038574219.
# Pairwise angle between m_6 and m_63 is: 1.8211623430252075.
# Pairwise angle between m_6 and m_64 is: 1.3590315580368042.
# Pairwise angle between m_6 and m_65 is: 1.5300120115280151.
# Pairwise angle between m_6 and m_66 is: 1.456209421157837.
# Pairwise angle between m_6 and m_67 is: 1.4831037521362305.
# Pairwise angle between m_6 and m_68 is: 1.5312600135803223.
# Pairwise angle between m_6 and m_69 is: 1.3589833974838257.
# Pairwise angle between m_6 and m_70 is: 1.672582745552063.
# Pairwise angle between m_6 and m_71 is: 1.364391565322876.
# Pairwise angle between m_6 and m_72 is: 1.35928475856781.
# Pairwise angle between m_6 and m_73 is: 2.064876079559326.
# Pairwise angle between m_6 and m_74 is: 2.1857497692108154.
# Pairwise angle between m_6 and m_75 is: 1.9979398250579834.
# Pairwise angle between m_6 and m_76 is: 1.3588440418243408.
# Pairwise angle between m_6 and m_77 is: 1.8562424182891846.
# Pairwise angle between m_6 and m_78 is: 1.5119003057479858.
# Pairwise angle between m_6 and m_79 is: 1.4590485095977783.
# Pairwise angle between m_6 and m_80 is: 1.3583073616027832.
# Pairwise angle between m_6 and m_81 is: 2.116447925567627.
# Pairwise angle between m_6 and m_82 is: 1.357450246810913.
# Pairwise angle between m_6 and m_83 is: 1.6186906099319458.
# Pairwise angle between m_6 and m_84 is: 1.6226940155029297.
# Pairwise angle between m_6 and m_85 is: 1.6622068881988525.
# Pairwise angle between m_6 and m_86 is: 2.00758695602417.
# Pairwise angle between m_6 and m_87 is: 1.3659040927886963.
# Pairwise angle between m_6 and m_88 is: 1.3572099208831787.
# Pairwise angle between m_6 and m_89 is: 1.3577054738998413.
# Pairwise angle between m_6 and m_90 is: 1.3585351705551147.
# Pairwise angle between m_6 and m_91 is: 1.3578064441680908.
# Pairwise angle between m_6 and m_92 is: 1.63250732421875.
# Pairwise angle between m_6 and m_93 is: 1.907015085220337.
# Pairwise angle between m_6 and m_94 is: 1.8201531171798706.
# Pairwise angle between m_6 and m_95 is: 1.3592069149017334.
# Pairwise angle between m_6 and m_96 is: 1.4134663343429565.
# Pairwise angle between m_6 and m_97 is: 1.672566533088684.
# Pairwise angle between m_6 and m_98 is: 1.358609676361084.
# Pairwise angle between m_6 and m_99 is: 1.4870604276657104.
# Pairwise angle between m_7 and m_0 is: 2.0348854064941406.
# Pairwise angle between m_7 and m_1 is: 1.3571237325668335.
# Pairwise angle between m_7 and m_2 is: 1.3572975397109985.
# Pairwise angle between m_7 and m_3 is: 1.6512231826782227.
# Pairwise angle between m_7 and m_4 is: 1.6393518447875977.
# Pairwise angle between m_7 and m_5 is: 1.8582866191864014.
# Pairwise angle between m_7 and m_6 is: 1.3612526655197144.
# Pairwise angle between m_7 and m_8 is: 2.0335447788238525.
# Pairwise angle between m_7 and m_9 is: 1.476442575454712.
# Pairwise angle between m_7 and m_10 is: 1.3590306043624878.
# Pairwise angle between m_7 and m_11 is: 1.3579117059707642.
# Pairwise angle between m_7 and m_12 is: 1.9267830848693848.
# Pairwise angle between m_7 and m_13 is: 1.3577415943145752.
# Pairwise angle between m_7 and m_14 is: 1.653183102607727.
# Pairwise angle between m_7 and m_15 is: 1.3666425943374634.
# Pairwise angle between m_7 and m_16 is: 1.3682643175125122.
# Pairwise angle between m_7 and m_17 is: 1.629694938659668.
# Pairwise angle between m_7 and m_18 is: 1.4641354084014893.
# Pairwise angle between m_7 and m_19 is: 1.9290388822555542.
# Pairwise angle between m_7 and m_20 is: 1.7312871217727661.
# Pairwise angle between m_7 and m_21 is: 1.5183179378509521.
# Pairwise angle between m_7 and m_22 is: 1.8190200328826904.
# Pairwise angle between m_7 and m_23 is: 1.7516131401062012.
# Pairwise angle between m_7 and m_24 is: 1.4888859987258911.
# Pairwise angle between m_7 and m_25 is: 1.638192057609558.
# Pairwise angle between m_7 and m_26 is: 1.362433910369873.
# Pairwise angle between m_7 and m_27 is: 1.671109676361084.
# Pairwise angle between m_7 and m_28 is: 1.3574810028076172.
# Pairwise angle between m_7 and m_29 is: 1.5389821529388428.
# Pairwise angle between m_7 and m_30 is: 2.0151240825653076.
# Pairwise angle between m_7 and m_31 is: 1.3586969375610352.
# Pairwise angle between m_7 and m_32 is: 1.9895145893096924.
# Pairwise angle between m_7 and m_33 is: 1.4089348316192627.
# Pairwise angle between m_7 and m_34 is: 1.7661699056625366.
# Pairwise angle between m_7 and m_35 is: 1.912360668182373.
# Pairwise angle between m_7 and m_36 is: 1.3791903257369995.
# Pairwise angle between m_7 and m_37 is: 1.3575849533081055.
# Pairwise angle between m_7 and m_38 is: 1.456783413887024.
# Pairwise angle between m_7 and m_39 is: 1.3587418794631958.
# Pairwise angle between m_7 and m_40 is: 1.4822611808776855.
# Pairwise angle between m_7 and m_41 is: 1.3580149412155151.
# Pairwise angle between m_7 and m_42 is: 1.3593006134033203.
# Pairwise angle between m_7 and m_43 is: 1.6204438209533691.
# Pairwise angle between m_7 and m_44 is: 1.357971429824829.
# Pairwise angle between m_7 and m_45 is: 1.373011589050293.
# Pairwise angle between m_7 and m_46 is: 1.6745866537094116.
# Pairwise angle between m_7 and m_47 is: 1.3572430610656738.
# Pairwise angle between m_7 and m_48 is: 1.3580272197723389.
# Pairwise angle between m_7 and m_49 is: 1.3588675260543823.
# Pairwise angle between m_7 and m_50 is: 1.7957574129104614.
# Pairwise angle between m_7 and m_51 is: 1.439131259918213.
# Pairwise angle between m_7 and m_52 is: 1.357779860496521.
# Pairwise angle between m_7 and m_53 is: 1.9901576042175293.
# Pairwise angle between m_7 and m_54 is: 1.4305552244186401.
# Pairwise angle between m_7 and m_55 is: 1.5311193466186523.
# Pairwise angle between m_7 and m_56 is: 1.3590965270996094.
# Pairwise angle between m_7 and m_57 is: 1.7100791931152344.
# Pairwise angle between m_7 and m_58 is: 1.4079362154006958.
# Pairwise angle between m_7 and m_59 is: 1.8273394107818604.
# Pairwise angle between m_7 and m_60 is: 1.612798810005188.
# Pairwise angle between m_7 and m_61 is: 1.9917731285095215.
# Pairwise angle between m_7 and m_62 is: 1.35930335521698.
# Pairwise angle between m_7 and m_63 is: 1.4751147031784058.
# Pairwise angle between m_7 and m_64 is: 1.858229637145996.
# Pairwise angle between m_7 and m_65 is: 1.3582910299301147.
# Pairwise angle between m_7 and m_66 is: 2.1557857990264893.
# Pairwise angle between m_7 and m_67 is: 1.792500376701355.
# Pairwise angle between m_7 and m_68 is: 1.3572719097137451.
# Pairwise angle between m_7 and m_69 is: 1.8278392553329468.
# ...
# Pairwise angle between m_97 and m_34 is: 1.3587610721588135.
# Pairwise angle between m_97 and m_35 is: 1.755108118057251.
# Pairwise angle between m_97 and m_36 is: 1.3597568273544312.
# Pairwise angle between m_97 and m_37 is: 1.3581526279449463.
# Pairwise angle between m_97 and m_38 is: 1.3838945627212524.
# Pairwise angle between m_97 and m_39 is: 1.3574408292770386.
# Pairwise angle between m_97 and m_40 is: 1.358386516571045.
# Pairwise angle between m_97 and m_41 is: 1.3590518236160278.
# Pairwise angle between m_97 and m_42 is: 1.9048525094985962.
# Pairwise angle between m_97 and m_43 is: 1.5887855291366577.
# Pairwise angle between m_97 and m_44 is: 1.8812382221221924.
# Pairwise angle between m_97 and m_45 is: 2.073352098464966.
# Pairwise angle between m_97 and m_46 is: 1.5212606191635132.
# Pairwise angle between m_97 and m_47 is: 1.8126126527786255.
# Pairwise angle between m_97 and m_48 is: 1.7551827430725098.
# Pairwise angle between m_97 and m_49 is: 1.440969705581665.
# Pairwise angle between m_97 and m_50 is: 1.6112489700317383.
# Pairwise angle between m_97 and m_51 is: 1.6131350994110107.
# Pairwise angle between m_97 and m_52 is: 1.4081153869628906.
# Pairwise angle between m_97 and m_53 is: 1.3575835227966309.
# Pairwise angle between m_97 and m_54 is: 1.3579442501068115.
# Pairwise angle between m_97 and m_55 is: 1.518003225326538.
# Pairwise angle between m_97 and m_56 is: 1.9143054485321045.
# Pairwise angle between m_97 and m_57 is: 1.8307920694351196.
# Pairwise angle between m_97 and m_58 is: 1.6962974071502686.
# Pairwise angle between m_97 and m_59 is: 1.4636561870574951.
# Pairwise angle between m_97 and m_60 is: 1.5700832605361938.
# Pairwise angle between m_97 and m_61 is: 1.3590291738510132.
# Pairwise angle between m_97 and m_62 is: 1.8395719528198242.
# Pairwise angle between m_97 and m_63 is: 1.7973331212997437.
# Pairwise angle between m_97 and m_64 is: 1.3577228784561157.
# Pairwise angle between m_97 and m_65 is: 1.7021689414978027.
# Pairwise angle between m_97 and m_66 is: 1.6418650150299072.
# Pairwise angle between m_97 and m_67 is: 1.7053136825561523.
# Pairwise angle between m_97 and m_68 is: 2.0961661338806152.
# Pairwise angle between m_97 and m_69 is: 1.3877716064453125.
# Pairwise angle between m_97 and m_70 is: 1.67438805103302.
# Pairwise angle between m_97 and m_71 is: 1.5692516565322876.
# Pairwise angle between m_97 and m_72 is: 1.732683539390564.
# Pairwise angle between m_97 and m_73 is: 1.3585104942321777.
# Pairwise angle between m_97 and m_74 is: 1.3591618537902832.
# Pairwise angle between m_97 and m_75 is: 1.6945595741271973.
# Pairwise angle between m_97 and m_76 is: 1.3584868907928467.
# Pairwise angle between m_97 and m_77 is: 1.5629289150238037.
# Pairwise angle between m_97 and m_78 is: 1.5195469856262207.
# Pairwise angle between m_97 and m_79 is: 1.5156203508377075.
# Pairwise angle between m_97 and m_80 is: 1.5145317316055298.
# Pairwise angle between m_97 and m_81 is: 1.357980728149414.
# Pairwise angle between m_97 and m_82 is: 1.9755988121032715.
# Pairwise angle between m_97 and m_83 is: 1.3588390350341797.
# Pairwise angle between m_97 and m_84 is: 1.3588931560516357.
# Pairwise angle between m_97 and m_85 is: 1.7272191047668457.
# Pairwise angle between m_97 and m_86 is: 1.7203810214996338.
# Pairwise angle between m_97 and m_87 is: 1.457045316696167.
# Pairwise angle between m_97 and m_88 is: 2.0481679439544678.
# Pairwise angle between m_97 and m_89 is: 1.3689619302749634.
# Pairwise angle between m_97 and m_90 is: 1.8599135875701904.
# Pairwise angle between m_97 and m_91 is: 2.054763078689575.
# Pairwise angle between m_97 and m_92 is: 1.358007788658142.
# Pairwise angle between m_97 and m_93 is: 1.7229855060577393.
# Pairwise angle between m_97 and m_94 is: 1.4884206056594849.
# Pairwise angle between m_97 and m_95 is: 1.9405437707901.
# Pairwise angle between m_97 and m_96 is: 1.358534574508667.
# Pairwise angle between m_97 and m_98 is: 1.3594127893447876.
# Pairwise angle between m_97 and m_99 is: 1.3608434200286865.
# Pairwise angle between m_98 and m_0 is: 1.6037648916244507.
# Pairwise angle between m_98 and m_1 is: 1.7778353691101074.
# Pairwise angle between m_98 and m_2 is: 1.7933235168457031.
# Pairwise angle between m_98 and m_3 is: 1.8300385475158691.
# Pairwise angle between m_98 and m_4 is: 1.9129409790039062.
# Pairwise angle between m_98 and m_5 is: 1.710527777671814.
# Pairwise angle between m_98 and m_6 is: 1.358609676361084.
# Pairwise angle between m_98 and m_7 is: 1.5547678470611572.
# Pairwise angle between m_98 and m_8 is: 1.3574776649475098.
# Pairwise angle between m_98 and m_9 is: 1.8590490818023682.
# Pairwise angle between m_98 and m_10 is: 1.3575646877288818.
# Pairwise angle between m_98 and m_11 is: 1.3735144138336182.
# Pairwise angle between m_98 and m_12 is: 1.9392826557159424.
# Pairwise angle between m_98 and m_13 is: 1.9935612678527832.
# Pairwise angle between m_98 and m_14 is: 1.357799768447876.
# Pairwise angle between m_98 and m_15 is: 1.4217820167541504.
# Pairwise angle between m_98 and m_16 is: 1.6026432514190674.
# Pairwise angle between m_98 and m_17 is: 1.359322190284729.
# Pairwise angle between m_98 and m_18 is: 1.8128188848495483.
# Pairwise angle between m_98 and m_19 is: 1.887244462966919.
# Pairwise angle between m_98 and m_20 is: 1.4628721475601196.
# Pairwise angle between m_98 and m_21 is: 1.3574436902999878.
# Pairwise angle between m_98 and m_22 is: 1.357296109199524.
# Pairwise angle between m_98 and m_23 is: 1.4643348455429077.
# Pairwise angle between m_98 and m_24 is: 1.5591466426849365.
# Pairwise angle between m_98 and m_25 is: 1.3580204248428345.
# Pairwise angle between m_98 and m_26 is: 1.9266349077224731.
# Pairwise angle between m_98 and m_27 is: 1.3676964044570923.
# Pairwise angle between m_98 and m_28 is: 1.3569719791412354.
# Pairwise angle between m_98 and m_29 is: 1.3565007448196411.
# Pairwise angle between m_98 and m_30 is: 1.7280856370925903.
# Pairwise angle between m_98 and m_31 is: 1.6481995582580566.
# Pairwise angle between m_98 and m_32 is: 1.5882790088653564.
# Pairwise angle between m_98 and m_33 is: 1.3581598997116089.
# Pairwise angle between m_98 and m_34 is: 1.4040298461914062.
# Pairwise angle between m_98 and m_35 is: 1.9164717197418213.
# Pairwise angle between m_98 and m_36 is: 1.478292465209961.
# Pairwise angle between m_98 and m_37 is: 1.545498013496399.
# Pairwise angle between m_98 and m_38 is: 1.3932747840881348.
# Pairwise angle between m_98 and m_39 is: 1.358747959136963.
# Pairwise angle between m_98 and m_40 is: 1.3581756353378296.
# Pairwise angle between m_98 and m_41 is: 1.3577920198440552.
# Pairwise angle between m_98 and m_42 is: 1.6469497680664062.
# Pairwise angle between m_98 and m_43 is: 1.8493441343307495.
# Pairwise angle between m_98 and m_44 is: 2.1706628799438477.
# Pairwise angle between m_98 and m_45 is: 1.64874267578125.
# Pairwise angle between m_98 and m_46 is: 1.4294880628585815.
# Pairwise angle between m_98 and m_47 is: 1.3577929735183716.
# Pairwise angle between m_98 and m_48 is: 1.6484146118164062.
# Pairwise angle between m_98 and m_49 is: 1.5550273656845093.
# Pairwise angle between m_98 and m_50 is: 2.0397861003875732.
# Pairwise angle between m_98 and m_51 is: 1.3571691513061523.
# Pairwise angle between m_98 and m_52 is: 1.8831677436828613.
# Pairwise angle between m_98 and m_53 is: 1.908453345298767.
# Pairwise angle between m_98 and m_54 is: 1.3942444324493408.
# Pairwise angle between m_98 and m_55 is: 1.3578760623931885.
# Pairwise angle between m_98 and m_56 is: 1.4120241403579712.
# Pairwise angle between m_98 and m_57 is: 1.3574998378753662.
# Pairwise angle between m_98 and m_58 is: 1.6236008405685425.
# Pairwise angle between m_98 and m_59 is: 1.3577443361282349.
# Pairwise angle between m_98 and m_60 is: 1.3585870265960693.
# Pairwise angle between m_98 and m_61 is: 1.4394752979278564.
# Pairwise angle between m_98 and m_62 is: 1.3579286336898804.
# Pairwise angle between m_98 and m_63 is: 1.3573404550552368.
# Pairwise angle between m_98 and m_64 is: 1.795460820198059.
# Pairwise angle between m_98 and m_65 is: 1.3915787935256958.
# Pairwise angle between m_98 and m_66 is: 1.3610546588897705.
# Pairwise angle between m_98 and m_67 is: 1.8240995407104492.
# Pairwise angle between m_98 and m_68 is: 1.6221338510513306.
# Pairwise angle between m_98 and m_69 is: 1.4469386339187622.
# Pairwise angle between m_98 and m_70 is: 1.9057071208953857.
# Pairwise angle between m_98 and m_71 is: 1.6975061893463135.
# Pairwise angle between m_98 and m_72 is: 1.359222412109375.
# Pairwise angle between m_98 and m_73 is: 1.3574827909469604.
# Pairwise angle between m_98 and m_74 is: 1.9392167329788208.
# Pairwise angle between m_98 and m_75 is: 1.8820750713348389.
# Pairwise angle between m_98 and m_76 is: 1.635072946548462.
# Pairwise angle between m_98 and m_77 is: 1.358694076538086.
# Pairwise angle between m_98 and m_78 is: 2.0077497959136963.
# Pairwise angle between m_98 and m_79 is: 1.3572163581848145.
# Pairwise angle between m_98 and m_80 is: 1.3977627754211426.
# Pairwise angle between m_98 and m_81 is: 1.9880330562591553.
# Pairwise angle between m_98 and m_82 is: 1.3733811378479004.
# Pairwise angle between m_98 and m_83 is: 1.3577539920806885.
# Pairwise angle between m_98 and m_84 is: 1.7283849716186523.
# Pairwise angle between m_98 and m_85 is: 1.8402583599090576.
# Pairwise angle between m_98 and m_86 is: 1.6545655727386475.
# Pairwise angle between m_98 and m_87 is: 1.3589786291122437.
# Pairwise angle between m_98 and m_88 is: 1.8764692544937134.
# Pairwise angle between m_98 and m_89 is: 1.3571525812149048.
# Pairwise angle between m_98 and m_90 is: 1.778099536895752.
# Pairwise angle between m_98 and m_91 is: 1.8249667882919312.
# Pairwise angle between m_98 and m_92 is: 1.3583056926727295.
# Pairwise angle between m_98 and m_93 is: 2.0819480419158936.
# Pairwise angle between m_98 and m_94 is: 1.9440244436264038.
# Pairwise angle between m_98 and m_95 is: 1.5313738584518433.
# Pairwise angle between m_98 and m_96 is: 1.3579823970794678.
# Pairwise angle between m_98 and m_97 is: 1.3594127893447876.
# Pairwise angle between m_98 and m_99 is: 1.5244531631469727.
# Pairwise angle between m_99 and m_0 is: 1.360201120376587.
# Pairwise angle between m_99 and m_1 is: 1.3710925579071045.
# Pairwise angle between m_99 and m_2 is: 1.585790753364563.
# Pairwise angle between m_99 and m_3 is: 1.4902423620224.
# Pairwise angle between m_99 and m_4 is: 1.5712600946426392.
# Pairwise angle between m_99 and m_5 is: 1.3586575984954834.
# Pairwise angle between m_99 and m_6 is: 1.4870604276657104.
# Pairwise angle between m_99 and m_7 is: 1.8423786163330078.
# Pairwise angle between m_99 and m_8 is: 1.3603551387786865.
# Pairwise angle between m_99 and m_9 is: 1.456129550933838.
# Pairwise angle between m_99 and m_10 is: 1.4003454446792603.
# Pairwise angle between m_99 and m_11 is: 2.0783145427703857.
# Pairwise angle between m_99 and m_12 is: 1.376571774482727.
# Pairwise angle between m_99 and m_13 is: 1.4250872135162354.
# Pairwise angle between m_99 and m_14 is: 1.3603729009628296.
# Pairwise angle between m_99 and m_15 is: 1.597109079360962.
# Pairwise angle between m_99 and m_16 is: 1.3720808029174805.
# Pairwise angle between m_99 and m_17 is: 1.4296866655349731.
# Pairwise angle between m_99 and m_18 is: 1.359610915184021.
# Pairwise angle between m_99 and m_19 is: 1.7787940502166748.
# Pairwise angle between m_99 and m_20 is: 1.8681716918945312.
# Pairwise angle between m_99 and m_21 is: 1.3808479309082031.
# Pairwise angle between m_99 and m_22 is: 1.3612942695617676.
# Pairwise angle between m_99 and m_23 is: 1.462259292602539.
# Pairwise angle between m_99 and m_24 is: 1.909584403038025.
# Pairwise angle between m_99 and m_25 is: 1.825677752494812.
# Pairwise angle between m_99 and m_26 is: 2.100679874420166.
# Pairwise angle between m_99 and m_27 is: 1.7852928638458252.
# Pairwise angle between m_99 and m_28 is: 1.8312498331069946.
# Pairwise angle between m_99 and m_29 is: 1.5501725673675537.
# Pairwise angle between m_99 and m_30 is: 1.358597993850708.
# Pairwise angle between m_99 and m_31 is: 1.842714786529541.
# Pairwise angle between m_99 and m_32 is: 1.9572861194610596.
# Pairwise angle between m_99 and m_33 is: 1.419764757156372.
# Pairwise angle between m_99 and m_34 is: 1.359727382659912.
# Pairwise angle between m_99 and m_35 is: 1.4493333101272583.
# Pairwise angle between m_99 and m_36 is: 1.359635591506958.
# Pairwise angle between m_99 and m_37 is: 1.3601133823394775.
# Pairwise angle between m_99 and m_38 is: 1.3600916862487793.
# Pairwise angle between m_99 and m_39 is: 1.35964035987854.
# Pairwise angle between m_99 and m_40 is: 1.8138480186462402.
# Pairwise angle between m_99 and m_41 is: 1.3606157302856445.
# Pairwise angle between m_99 and m_42 is: 1.710888147354126.
# Pairwise angle between m_99 and m_43 is: 1.3595855236053467.
# Pairwise angle between m_99 and m_44 is: 1.3588453531265259.
# Pairwise angle between m_99 and m_45 is: 1.9550048112869263.
# Pairwise angle between m_99 and m_46 is: 1.3598523139953613.
# Pairwise angle between m_99 and m_47 is: 1.4896656274795532.
# Pairwise angle between m_99 and m_48 is: 1.8023936748504639.
# Pairwise angle between m_99 and m_49 is: 1.3589376211166382.
# Pairwise angle between m_99 and m_50 is: 1.6371389627456665.
# Pairwise angle between m_99 and m_51 is: 1.3598551750183105.
# Pairwise angle between m_99 and m_52 is: 1.9447991847991943.
# Pairwise angle between m_99 and m_53 is: 1.7259891033172607.
# Pairwise angle between m_99 and m_54 is: 1.8050780296325684.
# Pairwise angle between m_99 and m_55 is: 1.8450703620910645.
# Pairwise angle between m_99 and m_56 is: 1.4076776504516602.
# Pairwise angle between m_99 and m_57 is: 1.6573293209075928.
# Pairwise angle between m_99 and m_58 is: 1.599759817123413.
# Pairwise angle between m_99 and m_59 is: 1.4192824363708496.
# Pairwise angle between m_99 and m_60 is: 1.3593040704727173.
# Pairwise angle between m_99 and m_61 is: 1.3599956035614014.
# Pairwise angle between m_99 and m_62 is: 1.851355791091919.
# Pairwise angle between m_99 and m_63 is: 1.7228323221206665.
# Pairwise angle between m_99 and m_64 is: 1.3643978834152222.
# Pairwise angle between m_99 and m_65 is: 1.3948637247085571.
# Pairwise angle between m_99 and m_66 is: 1.3606171607971191.
# Pairwise angle between m_99 and m_67 is: 1.359319806098938.
# Pairwise angle between m_99 and m_68 is: 1.3594086170196533.
# Pairwise angle between m_99 and m_69 is: 1.5964232683181763.
# Pairwise angle between m_99 and m_70 is: 1.7885878086090088.
# Pairwise angle between m_99 and m_71 is: 1.420965552330017.
# Pairwise angle between m_99 and m_72 is: 2.110412836074829.
# Pairwise angle between m_99 and m_73 is: 1.4059933423995972.
# Pairwise angle between m_99 and m_74 is: 1.3584997653961182.
# Pairwise angle between m_99 and m_75 is: 1.6277251243591309.
# Pairwise angle between m_99 and m_76 is: 1.5172890424728394.
# Pairwise angle between m_99 and m_77 is: 1.7420098781585693.
# Pairwise angle between m_99 and m_78 is: 1.5268977880477905.
# Pairwise angle between m_99 and m_79 is: 2.0604376792907715.
# Pairwise angle between m_99 and m_80 is: 1.9566760063171387.
# Pairwise angle between m_99 and m_81 is: 1.6707303524017334.
# Pairwise angle between m_99 and m_82 is: 1.9101059436798096.
# Pairwise angle between m_99 and m_83 is: 1.4946609735488892.
# Pairwise angle between m_99 and m_84 is: 1.9425750970840454.
# Pairwise angle between m_99 and m_85 is: 1.3597068786621094.
# Pairwise angle between m_99 and m_86 is: 1.3815592527389526.
# Pairwise angle between m_99 and m_87 is: 1.693871021270752.
# Pairwise angle between m_99 and m_88 is: 2.0020532608032227.
# Pairwise angle between m_99 and m_89 is: 1.3658802509307861.
# Pairwise angle between m_99 and m_90 is: 1.3593508005142212.
# Pairwise angle between m_99 and m_91 is: 1.6169078350067139.
# Pairwise angle between m_99 and m_92 is: 1.3608304262161255.
# Pairwise angle between m_99 and m_93 is: 2.0636332035064697.
# Pairwise angle between m_99 and m_94 is: 1.701286792755127.
# Pairwise angle between m_99 and m_95 is: 1.9563511610031128.
# Pairwise angle between m_99 and m_96 is: 1.8043519258499146.
# Pairwise angle between m_99 and m_97 is: 1.3608434200286865.
# Pairwise angle between m_99 and m_98 is: 1.5244531631469727.
